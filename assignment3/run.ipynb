# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs224n/assignments/assignment3/'
FOLDERNAME = 'cs224n/assignments/assignment3/'

assert FOLDERNAME is not None, "[!] Enter the foldername."
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# /content/drive/My Drive/cs224n/assignments/assignment3

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.2 MB/s eta 0:00:00

# %%
# !cd tests && pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/My Drive/cs224n/assignments/assignment3
# configfile: pytest.ini
# plugins: jaxtyping-0.3.11, langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 6 items
#
# test_student.py::test_mlp PASSED                                         [ 16%]
# test_student.py::test_attention PASSED                                   [ 33%]
# test_student.py::test_decoder_block PASSED                               [ 50%]
# test_student.py::test_forward PASSED                                     [ 66%]
# test_student.py::test_generate PASSED                                    [ 83%]
# test_student.py::test_loss_on_batch PASSED                               [100%]
#
# ============================== 6 passed in 24.96s ==============================

# %%
# !python train.py
# Out:
# Using GPU
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 665/665 [00:00<00:00, 3.14MB/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 143kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 40.3MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 4.49MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 6.32MB/s]
# README.md: 100% 1.06k/1.06k [00:00<00:00, 2.97MB/s]
#
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:   0% 0.00/249M [00:00<?, ?B/s]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  16% 39.7M/249M [00:01<00:03, 60.1MB/s, 2.53MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): reconstructing file:   0% 909k/249M [00:01<06:19, 653kB/s, 46.4kB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): reconstructing file:   1% 1.94M/249M [00:01<02:41, 1.53MB/s, 86.4kB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  21% 52.2M/249M [00:01<00:04, 44.4MB/s, 4.68MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  40% 101M/249M [00:02<00:01, 101MB/s, 6.00MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  52% 130M/249M [00:02<00:00, 136MB/s, 9.33MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  67% 167M/249M [00:02<00:00, 185MB/s, 12.0MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  79% 197M/249M [00:02<00:00, 213MB/s, 15.4MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): reconstructing file:  37% 92.3M/249M [00:02<00:00, 162MB/s, 3.39MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes:  94% 234M/249M [00:02<00:00, 201MB/s, 20.1MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): downloading bytes: 100% 248M/248M [00:02<00:00, 86.5MB/s, 22.1MB/s  ]
# data/train-00000-of-00004-2d5a1467fff108(…): reconstructing file: 100% 249M/249M [00:02<00:00, 86.8MB/s, 22.9MB/s  ]
#
# data/train-00001-of-00004-5852b56a2bd28f(…): downloading bytes: 100% 247M/248M [00:01<00:00, 254MB/s, 22.4MB/s  ]
# data/train-00001-of-00004-5852b56a2bd28f(…): downloading bytes: 100% 247M/247M [00:01<00:00, 128MB/s, 23.3MB/s  ]
# data/train-00001-of-00004-5852b56a2bd28f(…): reconstructing file: 100% 248M/248M [00:01<00:00, 128MB/s, 23.7MB/s  ]
#
# data/train-00002-of-00004-a26307300439e9(…): downloading bytes:  99% 244M/246M [00:01<00:00, 247MB/s, 21.7MB/s  ]
# data/train-00002-of-00004-a26307300439e9(…): downloading bytes: 100% 245M/245M [00:02<00:00, 102MB/s, 22.8MB/s  ]
# data/train-00002-of-00004-a26307300439e9(…): reconstructing file: 100% 246M/246M [00:02<00:00, 102MB/s, 23.1MB/s  ]
#
# data/train-00003-of-00004-d243063613e5a0(…): downloading bytes:  90% 224M/248M [00:01<00:00, 293MB/s, 17.4MB/s  ]
# data/train-00003-of-00004-d243063613e5a0(…): reconstructing file:  27% 67.1M/248M [00:05<00:15, 11.5MB/s]
# data/train-00003-of-00004-d243063613e5a0(…): downloading bytes: 100% 247M/247M [00:06<00:00, 40.9MB/s, 23.2MB/s  ]
# data/train-00003-of-00004-d243063613e5a0(…): reconstructing file: 100% 248M/248M [00:06<00:00, 41.0MB/s, 21.5MB/s  ]
#
# data/validation-00000-of-00001-869c898b5(…): downloading bytes:  33% 3.31M/9.99M [00:00<00:01, 6.39MB/s]
# data/validation-00000-of-00001-869c898b5(…): downloading bytes: 100% 9.95M/9.95M [00:00<00:00, 16.6MB/s,  982kB/s  ]
# data/validation-00000-of-00001-869c898b5(…): reconstructing file: 100% 9.99M/9.99M [00:00<00:00, 16.6MB/s,  987kB/s  ]
# Generating train split: 100% 2119719/2119719 [00:16<00:00, 127772.84 examples/s]
# Generating validation split: 100% 21990/21990 [00:00<00:00, 190958.46 examples/s]
# Tokenizing dataset: 100% 21197/21197 [00:14<00:00, 1495.70it/s]
# Training: 100% 100/100 [00:21<00:00,  4.73it/s]

# %%
# !bash create_submission.sh
# Out:
# Creating student submission zip...
# Adding: model_solution.py
# Adding: utils.py
# Adding: train.py
#
# ✓ Submission created: submission.zip
# ✓ Ready to upload to Gradescope!
#
# Files included:
# Archive:  submission.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#      7563  2026-08-25 09:00   model_solution.py
#     16400  2026-08-25 09:00   utils.py
#      4881  2026-08-25 09:00   train.py
# ---------                     -------
#     28844                     3 files
