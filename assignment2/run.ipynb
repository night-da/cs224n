# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs224n/assignments/assignment2/'
FOLDERNAME = 'cs224n/assignments/assignment2/'

assert FOLDERNAME is not None, "[!] Enter the foldername."
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# /content/drive/My Drive/cs224n/assignments/assignment2

# %%
# !python run.py
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Loading data...
# took 1.61 seconds
# Building parser...
# took 1.44 seconds
# Loading pretrained embeddings...
# took 2.51 seconds
# Vectorizing data...
# took 1.22 seconds
# Preprocessing training data...
# took 27.68 seconds
# took 0.00 seconds
#
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 10
# 100% 1848/1848 [01:39<00:00, 18.63it/s]
# Average Train Loss: 0.1851222680446196
# Evaluating on dev set
# 1445850it [00:00, 58991580.14it/s]
# - dev UAS: 83.80
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [01:40<00:00, 18.40it/s]
# Average Train Loss: 0.11408381565631211
# Evaluating on dev set
# 1445850it [00:00, 71988775.38it/s]
# - dev UAS: 85.76
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 1848/1848 [01:40<00:00, 18.44it/s]
# Average Train Loss: 0.09990563999772781
# Evaluating on dev set
# 1445850it [00:00, 80593446.01it/s]
# - dev UAS: 86.95
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# 100% 1848/1848 [01:41<00:00, 18.28it/s]
# Average Train Loss: 0.0916759385203225
# Evaluating on dev set
# 1445850it [00:00, 79395850.26it/s]
# - dev UAS: 87.64
# New best dev UAS! Saving model.
#
# Epoch 5 out of 10
# 100% 1848/1848 [01:37<00:00, 18.92it/s]
# Average Train Loss: 0.08523835636094793
# Evaluating on dev set
# 1445850it [00:00, 78952407.74it/s]
# - dev UAS: 88.02
# New best dev UAS! Saving model.
#
# Epoch 6 out of 10
# 100% 1848/1848 [01:37<00:00, 18.92it/s]
# Average Train Loss: 0.08024935888174872
# Evaluating on dev set
# 1445850it [00:00, 80947374.27it/s]
# - dev UAS: 88.33
# New best dev UAS! Saving model.
#
# Epoch 7 out of 10
# 100% 1848/1848 [01:41<00:00, 18.25it/s]
# Average Train Loss: 0.0761974104599487
# Evaluating on dev set
# 1445850it [00:00, 82548383.40it/s]
# - dev UAS: 88.39
# New best dev UAS! Saving model.
#
# Epoch 8 out of 10
# 100% 1848/1848 [01:42<00:00, 18.04it/s]
# Average Train Loss: 0.07255101280923916
# Evaluating on dev set
# 1445850it [00:00, 79923223.62it/s]
# - dev UAS: 88.68
# New best dev UAS! Saving model.
#
# Epoch 9 out of 10
# 100% 1848/1848 [01:43<00:00, 17.80it/s]
# Average Train Loss: 0.06925305857391649
# Evaluating on dev set
# 1445850it [00:00, 80375539.28it/s]
# - dev UAS: 88.45
#
# Epoch 10 out of 10
# 100% 1848/1848 [01:42<00:00, 18.01it/s]
# Average Train Loss: 0.06640410176740387
# Evaluating on dev set
# 1445850it [00:00, 42217511.49it/s]
# - dev UAS: 88.82
# New best dev UAS! Saving model.
#
# ================================================================================
# TESTING
# ================================================================================
# Restoring the best model weights found on the dev set
# Final evaluation on test set
# 2919736it [00:00, 112283024.81it/s]
# - test UAS: 89.15
# Done!

# %% [markdown]
# # Collect Submission

# %%
# !bash collect_submission.sh
# Out:
#   adding: parser_model.py (deflated 68%)
#   adding: parser_transitions.py (deflated 73%)
#   adding: run.py (deflated 64%)
#   adding: utils/ (stored 0%)
#   adding: utils/general_utils.py (deflated 62%)
#   adding: utils/parser_utils.py (deflated 75%)
